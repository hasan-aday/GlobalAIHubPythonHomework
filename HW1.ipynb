# %%
liste = list()
a = int(input("Please enter an integer: "))
liste.append(a)
b = str(input("Please enter an string: "))
liste.append(b)
c = float(input("Please enter an float: "))
liste.append(c)
d = bool(input("Please enter an boolean: "))
liste.append(d)
e =input("Please enter an normal: ")
liste.append(e)

print(f"a : {a}\nb: {b} \nc : {c} \nd : {d} \ne : {e}")


print("a type : {} \nb type : {} \nc type : {} \nd type : {} \ne type : {}".format(type(liste[0]), type(liste[1]), type(liste[2]), type(liste[3]), type(liste[4])))
# Out:
# Please enter an integer:  1
# Please enter an string:  s
# Please enter an float:  1.2
# Please enter an boolean:  3,5
# Please enter an normal:  dd
# a : 1
# b: s
# c : 1.2
# d : True
# e : dd
# a type : <class 'int'>
# b type : <class 'str'>
# c type : <class 'float'>
# d type : <class 'bool'>
# e type : <class 'str'>
